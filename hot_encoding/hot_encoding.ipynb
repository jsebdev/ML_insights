# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier, export_graphviz
import graphviz

# %%
df = pd.DataFrame({'x':['si', 'no', 'tal vez', 'jaja', 'pues...'] * 10,
                  'y': [1,0,0,0,0] * 10})
dummies = pd.get_dummies(df.x)
y = df.y
# new_df = pd.concat((df,dummies), axis=1)
model = DecisionTreeClassifier().fit(dummies, y)
dot_data = export_graphviz(model, out_file=None,
                                feature_names=dummies.columns,
                                class_names=['Not survived', 'Survived'],  
                                filled=True,
                                rounded=True
                               ) 
graph = graphviz.Source(dot_data) 
graph

# %%
df = pd.DataFrame({'x':['si', 'no', 'tal vez', 'jaja', 'pues...'] * 10,
                  'y': [1,0,0,0,0] * 10})
dummies = pd.get_dummies(df.x)
dummies.pop('no')
y = df.y
# new_df = pd.concat((df,dummies), axis=1)
model = DecisionTreeClassifier().fit(dummies, y)
dot_data = export_graphviz(model, out_file=None,
                                feature_names=dummies.columns,
                                class_names=['Not survived', 'Survived'],  
                                filled=True,
                                rounded=True
                               ) 
graph = graphviz.Source(dot_data) 
graph

# %%
df = pd.DataFrame({'x':['si', 'no', 'tal vez', 'jaja', 'pues...'] * 10,
                  'y': [1,0,0,0,0] * 10})
dummies = pd.get_dummies(df.x)
dummies.pop('si')
y = df.y
# new_df = pd.concat((df,dummies), axis=1)
model = DecisionTreeClassifier().fit(dummies, y)
dot_data = export_graphviz(model, out_file=None,
                                feature_names=dummies.columns,
                                class_names=['Not survived', 'Survived'],  
                                filled=True,
                                rounded=True
                               ) 
graph = graphviz.Source(dot_data) 
graph
